# %%
import os

if "src" not in os.listdir():
    os.chdir("../../../")

from src.lib.price_history import *

# %%
spy = read_price_history("SPY")
spy.data
# Out:
#                              open    high     low   close  volume  trades  \
# time
# 2015-12-01 09:04:00+00:00  209.43  209.43  209.43  209.43     470       2
# 2015-12-01 09:05:00+00:00  209.35  209.35  209.32  209.32    1160       3
# 2015-12-01 09:06:00+00:00  209.42  209.42  209.42  209.42     100       1
# 2015-12-01 09:18:00+00:00  209.44  209.44  209.44  209.44    1000       1
# 2015-12-01 09:19:00+00:00  209.43  209.43  209.42  209.43     800       4
# ...                           ...     ...     ...     ...     ...     ...
# 2021-09-01 23:56:00+00:00  451.94  451.94  451.94  451.94     172       4
# 2021-09-01 23:57:00+00:00  451.97  451.97  451.97  451.97    1121       9
# 2021-09-01 23:58:00+00:00  451.98  451.98  451.98  451.98     497       9
# 2021-09-01 23:59:00+00:00  451.98  451.98  451.97  451.97    2101      16
# 2021-09-02 00:00:00+00:00  451.98  451.98  451.80  451.98     500       1
#
#                                  vwap
# time
# ...

# %%
spyt = transform_price_history(spy)
spyt.data
# Out:
#                               volume  trades    oc_ret  pdiff_open  \
# 2015-12-01 15:04:00+00:00   580694.0  2094.0 -0.000333    0.000333
# 2015-12-01 15:05:00+00:00   231778.0  1026.0 -0.000352    0.000352
# 2015-12-01 15:06:00+00:00   384257.0  1523.0  0.000334   -0.000333
# 2015-12-01 15:07:00+00:00   149677.0   741.0 -0.000048    0.000048
# 2015-12-01 15:08:00+00:00   720145.0  1094.0 -0.000024    0.000024
# ...                              ...     ...       ...         ...
# 2021-09-01 19:56:00+00:00   403151.0  2889.0  0.000033   -0.000033
# 2021-09-01 19:57:00+00:00   657835.0  3046.0 -0.000111    0.000111
# 2021-09-01 19:58:00+00:00   746829.0  3791.0 -0.000111    0.000111
# 2021-09-01 19:59:00+00:00  1403930.0  7331.0  0.000509   -0.000509
# 2021-09-01 20:00:00+00:00   931111.0   649.0  0.000354   -0.000354
#
#                            pdiff_high  pdiff_low  pdiff_vwap     ma_50  \
# 2015-12-01 15:04:00+00:00    0.000333  -0.000143   -0.000005  0.000079
# ...
